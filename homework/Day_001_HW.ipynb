# %%
#第一題MSE--------------------------------------------
import matplotlib.pyplot as plt
import numpy as np
w = 3
b = 0.5
x_lin = np.linspace(0,100,101)
y = (x_lin + np.random.randn(101)*5)*w + b
plt.plot(x_lin,y,'b.',label='data points')
plt.title("Assume we have data points")
plt.legend(loc=2)
plt.show()

# %%
y_hat = x_lin *w +b
plt.plot(x_lin,y,'b.',label='data')
plt.plot(x_lin,y_hat,'r-',label='prediction')
plt.title("Assime we have data points (And the prediction)")
plt.legend(loc=2)
plt.show()

# %%
def mean_absolute_error(y,yp):
    MAE = sum( abs(y-yp) )/len(y)
    return MAE

def mean_squared_error(y,yp):
    MSE = sum( (y-yp)**2 )/len(y)
    return MSE

MSE = mean_squared_error(y,y_hat)
MAE = mean_absolute_error(y,y_hat)

print("The Mean squared error is %.3f" % MSE)
print("The Mean absolute error is %.3f" % MAE)
# Out:
# The Mean squared error is 266.680
# The Mean absolute error is 13.049

# %%
#第二題---------------------------------------------------
'''
這次選的題目為Titanic: Machine Learning from Disaster

1. 你選的這組資料為何重要
A:(1)從歷史的警惕中學習(2)預測生存率(3)若預測模型準確率高,船運公司可做參考,思考是否能改善生存率低的乘客

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
A:鐵達尼號乘客名單

3. 蒐集而來的資料型態為何
A:結構化資料:CSV檔

4. 這組資料想解決的問題如何評估
A:哪些條件的乘客生存機率較高

'''
# Out:
# '\n這次選的題目為Titanic: Machine Learning from Disaster\n\n1. 你選的這組資料為何重要\nA:(1)從歷史的警惕中學習(2)預測生存率(3)若預測模型準確率高,船運公司可做參考,思考是否能改善生存率低的乘客\n\n2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)\nA:鐵達尼號乘客名單\n\n3. 蒐集而來的資料型態為何\nA:結構化資料:CSV檔\n\n4. 這組資料想解決的問題如何評估\nA:哪些條件的乘客生存機率較高\n\n'

# %%
#第三題------------------------------------------
'''
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
A:提升業績表示載客數上升,收入上升;假設:天氣與地點會影響業績

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
A:根據目前載客情況去蒐集資料,可記錄哪些地點人潮較多ex車站,或是下雨天也可能促使人們較願意搭乘

3. 蒐集而來的資料型態為何
A:表格:列為天氣,行為地點,值為載客數量

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
A:根據當日天氣決定去哪些地點會較有生意上門

'''
# Out:
# '\n1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)\nA:提升業績表示載客數上升,收入上升;假設:天氣與地點會影響業績\n\n2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)\nA:根據目前載客情況去蒐集資料,可記錄哪些地點人潮較多ex車站,或是下雨天也可能促使人們較願意搭乘\n\n3. 蒐集而來的資料型態為何\nA:表格:列為天氣,行為地點,值為載客數量\n\n4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)\nA:根據當日天氣決定去哪些地點會較有生意上門\n\n'
